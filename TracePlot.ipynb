# %% [markdown]
# ### Plotting raw calcium traces.
# input: `sigals_0.pkl`

# %%
# %matplotlib inline

# %%
import os
import pandas as pd
import seaborn as sns
sns.set()

import scipy as sp
from scipy.signal import savgol_filter as sf

# %%
os.chdir('/data/gergely/invivo_DATA/axonGCaMP7b/FS_SuM_recordings/TSeries-04242019-0804-016/TSeries-04242019-0804-016.sima/')

# %%
data = pd.read_pickle('signals_0.pkl')

# %%
data
# Out:
# {u'ROIs': {'mean_frame': array([[[ 73.32638674,  72.45290434,  75.38752743, ...,  73.54649917,
#             75.51043689,  76.82622345],
#           [ 72.35412702,  73.80729936,  73.6051258 , ...,  73.84487598,
#             74.89609708,  74.37974684],
#           [ 73.75160447,  73.64528502,  72.57280984, ...,  75.12841937,
#             75.88361114,  74.77994445],
#           ...,
#           [ 68.72271903,  68.41821896,  68.56031547, ...,  78.22293556,
#             76.59677129,  76.20073037],
#           [ 67.76571533,  67.73026634,  68.62250858, ...,  73.87259215,
#             76.17363383,  75.52113801],
#           [ 67.1630967 ,  66.81052439,  67.33501   , ...,  76.29083069,
#             75.54745773,  75.75394712]]]),
#   'overlap': (array([], dtype=int64), array([], dtype=int64)),
#   'raw': [array([[ 1.41383243,  1.38067591,  1.28783143, ...,  1.11709011,
#             0.83966976,  1.00911033],
#           [ 1.63580894,  1.55588448,  1.22417927, ...,  0.87062174,
# ...

# %%
numTraces = len(data['ROIs']['raw'][0])
numTraces
# Out:
# 11

# %%
# dictionary comprehension for details see: 
# https://www.youtube.com/watch?v=3dt4OGnU5sM @12:58

names = range(0,numTraces)
dataTraces = data['ROIs']['raw'][0]
dataDict = {name: traces for name, traces in zip(names, dataTraces)}

# %%
dataDict
# Out:
# {0: array([ 1.41383243,  1.38067591,  1.28783143, ...,  1.11709011,
#          0.83966976,  1.00911033], dtype=float32),
#  1: array([ 1.63580894,  1.55588448,  1.22417927, ...,  0.87062174,
#          0.91103256,  0.91352904], dtype=float32),
#  2: array([ 2.25374603,  2.02430296,  1.71083593, ...,  0.9338612 ,
#          1.00764978,  0.85188955], dtype=float32),
#  3: array([ 1.36120272,  1.62565219,  1.24827182, ...,  0.84639221,
#          1.07098305,  0.7923032 ], dtype=float32),
#  4: array([ 1.66592884,  1.43303764,  1.52546489, ...,  0.79011798,
#          0.90291625,  0.92711687], dtype=float32),
#  5: array([ 1.33057082,  1.25533581,  1.24795473, ...,  0.98823833,
#          0.99073279,  0.86516786], dtype=float32),
#  6: array([ 1.89866793,  1.51681304,  1.730744  , ...,  0.93691683,
#          0.77727276,  0.91094488], dtype=float32),
#  7: array([ 1.73133767,  1.57259381,  1.93061924, ...,  0.90705669,
#          0.9145937 ,  0.98114258], dtype=float32),
# ...

# %%
data1 = pd.DataFrame(dataDict)
data1.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.413832  1.635809  2.253746  1.361203  1.665929  1.330571  1.898668
# 1  1.380676  1.555884  2.024303  1.625652  1.433038  1.255336  1.516813
# 2  1.287831  1.224179  1.710836  1.248272  1.525465  1.247955  1.730744
# 3  1.183229  1.651779  1.707431  1.611247  1.491805  1.266327  1.515845
# 4  1.165103  1.132920  1.704623  1.085186  1.656082  1.260599  1.717232
#
#          7         8         9         10
# 0  1.731338  1.504545  1.294786  1.439976
# 1  1.572594  1.176589  1.123199  1.969547
# 2  1.930619  1.369920  1.336189  1.617647
# 3  1.376240  1.426951  1.148077  2.050230
# 4  1.542170  1.323938  1.054427  1.772296

# %%
data1.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f33a85d1710>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f33a814a910>], dtype=object)

# %%
def savgolFilter(df):
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-cc9f7e486f89> in <module>()
# ----> 1 dataFilter = sf(data1, window_length=29, polyorder=3)
#
# /home/gergely/anaconda2/lib/python2.7/site-packages/scipy/signal/_savitzky_golay.pyc in savgol_filter(x, window_length, polyorder, deriv, delta, axis, mode, cval)
#     342         # the last `window_length` elements.
#     343         y = convolve1d(x, coeffs, axis=axis, mode="constant")
# --> 344         _fit_edges_polyfit(x, window_length, polyorder, deriv, delta, axis, y)
#     345     else:
#     346         # Any mode other than 'interp' is passed on to ndimage.convolve1d.
#
# /home/gergely/anaconda2/lib/python2.7/site-packages/scipy/signal/_savitzky_golay.pyc in _fit_edges_polyfit(x, window_length, polyorder, deriv, delta, axis, y)
#     215     halflen = window_length // 2
# ...
